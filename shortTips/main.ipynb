# %%
import pandas as pd

seventeen = {
    'member' : ['babe', 'mingyu', 'DK', 'Maung'],
    'born' : [1995, 1997, 1997, 1996],
    'pcc' : ['leader', 'visual', 'vocal', 'dancer']
}

print(type(seventeen))
# Out:
# <class 'dict'>

# %%
# Dataframe ???
svt_df = pd.DataFrame(seventeen)
svt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   member  4 non-null      object
#  1   born    4 non-null      int64
#  2   pcc     4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes

# %%
# Series ???
svt_sr = svt_df['pcc']
svt_sr.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 4 entries, 0 to 3
# Series name: pcc
# Non-Null Count  Dtype
# --------------  -----
# 4 non-null      object
# dtypes: object(1)
# memory usage: 164.0+ bytes

# %%
# Dataframe itu array 2D (BARIS + KOLOM)
# Series itu array 1D
